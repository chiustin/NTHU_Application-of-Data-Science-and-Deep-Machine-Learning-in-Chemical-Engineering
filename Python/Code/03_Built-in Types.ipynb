# %% [markdown]
# # Variable

# %%
rho           = 997 #kg/m^3
velocity      = 1.00 #m/s
diameter      = 0.08 #80mm
viscosity     = 0.98 #cP
Renold_number = rho * velocity * diameter / viscosity

# %% [markdown]
# # String

# %% [markdown]
# ## Index

# %%
a = 'NTHUCHE'
print(a[0]) # character in position 0 => 'N' 
print(a[6]) # character in position 5 => 'E'
print(a[-1]) # last character => 'E'
print(a[-2]) # second-last character => 'H'
print(a[-7]) # => 'N'
# Out:
# N
# E
# E
# H
# N

# %% [markdown]
# ## Slice

# %%
a = 'NTHUCHE'
print(a[0:2]) # characters from position 0 (included) to 2 (excluded) => 'NT'
print(a[5:7]) # characters from position 5 (included) to 7 (excluded) => 'HE'
print(a[:2]) # character from the beginning to position 2 (excluded) => 'NT' 
print(a[5:]) # characters from position 5 (included) to the end => 'HE'
print(a[-3:]) # characters from the third-last (included) to the end => 'CHE'
print(a[0:7:2]) # => 'NHCE'
print(a[::2]) # => 'NHCE'
print(a[0:6:-2]) # => ' '
print(a[6:0:-2]) # => 'ECH'
print(a[::-2]) # => 'ECHN'
# Out:
# NT
# HE
# NT
# HE
# CHE
# NHCE
# NHCE
#
# ECH
# ECHN

# %%
print(a[42]) # error
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-4-9492d478db74> in <module>
# ----> 1 print(a[42]) # error
#
# IndexError: string index out of range

# %%
a = 'NTHUCHE'
print(a[4:42]) # => 'CHE'
print(a[42:]) # => ' '
print(a[:]) # => 'NTHUCHE'
# Out:
# CHE
#
# NTHUCHE

# %% [markdown]
# ## Immutable

# %%
a = 'NTHUCHE'
print(a[0] = 'C') # error
print(a[2:] = 'NU') # error
# Out:
#   File "<ipython-input-6-8d4402deb826>", line 2
#     print(a[0] = 'C') # error
#          ^
# SyntaxError: keyword can't be an expression

# %% [markdown]
# ## len

# %%
a = 'NTHUCHE'
print(len(a)) # => 7
# Out:
# 7

# %% [markdown]
# ## Operators

# %%
a = 'NTHUCHE'
print(a[:2] + a[2:]) # => 'NTHUCHE' 
print(a[:4] * 2) # => 'NTHUNTHU'
# Out:
# NTHUCHE
# NTHUNTHU

# %% [markdown]
# # List

# %% [markdown]
# ## Index

# %%
a = [1, 3, 5, 7, 9, 11]
print(a[0]) # indexing returns the item 1 
print(a[-1]) # => 11
# Out:
# 1
# 11

# %% [markdown]
# ## Slice

# %%
print(a[0:2]) # => [1, 3]
print(a[4:6]) # => [9, 11] 
print(a[:2]) # => [1, 3] 
print(a[4:]) # => [9, 11]
print(a[0:6:2]) # => [1, 5, 9] 
print(a[::2]) # => [1, 5, 9] 
print(a[6:0:-2]) # => [11, 7, 3]
print(a[0:6:-2]) # => [ ]  
print(a[::-2]) # => [11, 7, 3]
print(a[:]) # => [1, 3, 5, 7, 9, 11]
# Out:
# [1, 3]
# [9, 11]
# [1, 3]
# [9, 11]
# [1, 5, 9]
# [1, 5, 9]
# [11, 7, 3]
# []
# [11, 7, 3]
# [1, 3, 5, 7, 9, 11]

# %% [markdown]
# ## Mutable

# %%
a[-1] = 13
print(a) # => [1, 3, 5, 7, 9, 13]
# Out:
# [1, 3, 5, 7, 9, 13]

# %% [markdown]
# ## len

# %%
print(len(a)) # => 6
# Out:
# 6

# %% [markdown]
# ## Operators

# %%
a = [1, 3]; print(a)
a += [5, 7]; print(a) # => [1, 3, 5, 7]
a *= 2; print(a) # => [1, 3, 5, 7, 1, 3, 5, 7]
# Out:
# [1, 3]
# [1, 3, 5, 7]
# [1, 3, 5, 7, 1, 3, 5, 7]

# %% [markdown]
# # Mutability

# %%
a = [1,]
c = b = a #a must be placed at the last position
print('Print1:', 'a =', a, ', b =', b, ', c =', c)

a[0] = 2
print('Print2:', 'a =', a, ', b =', b, ', c =', c)

b[0] = 3
print('Print3:', 'a =', a, ', b =', b, ', c =', c)

c[0] = 4
print('Print4:', 'a =', a, ', b =', b, ', c =', c)
# Out:
# Print1: a = [1] , b = [1] , c = [1]
# Print2: a = [2] , b = [2] , c = [2]
# Print3: a = [3] , b = [3] , c = [3]
# Print4: a = [4] , b = [4] , c = [4]

# %% [markdown]
# # Dynamic

# %%
a = [1,]
c = b = a #a must be placed at the last position
print('Print1:', 'a =', a, ', b =', b, ', c =', c)

a.append(2) 
print('Print2:', 'a =', a, ', b =', b, ', c =', c)

b += [3]
print('Print3:', 'a =', a, ', b =', b, ', c =', c)
# Out:
# Print1: a = [1] , b = [1] , c = [1]
# Print2: a = [1, 2] , b = [1, 2] , c = [1, 2]
# Print3: a = [1, 2, 3] , b = [1, 2, 3] , c = [1, 2, 3]

# %% [markdown]
# # = vs. +=

# %%
a = [1,]
c = b = a #a must be placed at the last position
print('Print1:', 'a =', a, ', b =', b, ', c =', c)

b += [2,] #List mutable
print('Print2:', 'a =', a, ', b =', b, ', c =', c)

c = a + [3,]
print('Print3:', 'a =', a, ', b =', b, ', c =', c)
# Out:
# Print1: a = [1] , b = [1] , c = [1]
# Print2: a = [1, 2] , b = [1, 2] , c = [1, 2]
# Print3: a = [1, 2] , b = [1, 2] , c = [1, 2, 3]

# %%
a = [1,]
c = b = a #a must be placed at the last position
print('Print1:', 'a =', a, ', b =', b, ', c =', c)

b[0] = b[0] + 2 #List mutable
print('Print2:', 'a =', a, ', b =', b, ', c =', c)

c = a + [4,]
print('Print3:', 'a =', a, ', b =', b, ', c =', c)
# Out:
# Print1: a = [1] , b = [1] , c = [1]
# Print2: a = [3] , b = [3] , c = [3]
# Print3: a = [3] , b = [3] , c = [3, 4]

# %% [markdown]
# # List Copy

# %%
a = [1,]
b = list(a)
c = a[:]
d = a.copy()

a += [2,]
print('Print:', 'a =', a, ', b =', b, ', c =', c, ', d =', d)
# Out:
# Print: a = [1, 2] , b = [1] , c = [1] , d = [1]

# %% [markdown]
# # Shallow Copy vs. Deep Copy

# %%
a = [1,[2,3]]
b = a.copy()
print('Shallow copy: a =', a, ', b =',b)

b[0] = 5
b[1][1] = 6
print('Shallow copy: a =', a, ', b =',b)

import copy
a = [1,[2,3]]
b = copy.deepcopy(a)
print('Deep copy: a =', a, ', b =',b)

b[0] = 5
b[1][1] = 6
print('Deep copy: a =', a, ', b =',b)
# Out:
# Shallow copy: a = [1, [2, 3]] , b = [1, [2, 3]]
# Shallow copy: a = [1, [2, 6]] , b = [5, [2, 6]]
# Deep copy: a = [1, [2, 3]] , b = [1, [2, 3]]
# Deep copy: a = [1, [2, 3]] , b = [5, [2, 6]]

# %% [markdown]
# # Mutability vs Immutability

# %% [markdown]
# # List

# %%
a = [1,]
b = a #a must be placed at the last position
print('Print1:', 'a =', a, ', b =', b)

a += [2,]
print('Print2:', 'a =', a, ', b =', b)
# Out:
# Print1: a = [1] , b = [1]
# Print2: a = [1, 2] , b = [1, 2]

# %% [markdown]
# # Tuple

# %%
a = (1,)
b = a #a must be placed at the last position
print('Print1:', 'a =', a, ', b =', b)

a += (2,)
print('Print2:', 'a =', a, ', b =', b)
# Out:
# Print1: a = (1,) , b = (1,)
# Print2: a = (1, 2) , b = (1,)

# %% [markdown]
# # Reassigning Tuples

# %%
a = (1, 2, 3, [4, 5])
a[3] = 6
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-22-5b7261a67da2> in <module>
#       1 a = (1, 2, 3, [4, 5])
# ----> 2 a[3] = 6
#
# TypeError: 'tuple' object does not support item assignment

# %%
a = (1, 2, 3, [4, 5])
a[3][0] = 6           ; print(a)
# Out:
# (1, 2, 3, [6, 5])

# %% [markdown]
# # Range

# %% [markdown]
# ## Index

# %%
a = range(6)
print(a[2]) # => 2
print(a[-1]) # => 5
# Out:
# 2
# 5

# %%
a = range(0, 12, 2)
print(a[2]) # => 4
print(a[-1]) # => 10
# Out:
# 4
# 10

# %% [markdown]
# ## Immutable

# %%
a = range(6)
a[-1] = 13 # error
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-26-052b8c4fe4c5> in <module>
#       1 a = range(6)
# ----> 2 a[-1] = 13 # error
#
# TypeError: 'range' object does not support item assignment

# %% [markdown]
# # Dict

# %% [markdown]
# ## Keys & Values

# %%
a = {'a': 1, 'b': 3, 'c': 5, 'd': 7} 
print(a['a']) # => 1
print(a['c']) # => 5
d = {'int': 1, 'float': 2.2, 'bool': True} 
print(d['float']) # => 2.2
d = {(1, 1): 'a', (1, 2): 'b', (2, 1): 'c'} 
print(d[(1,1)]) # => 'a' 
print(d[(2,1)]) # => 'c'
# Out:
# 1
# 5
# 2.2
# a
# c

# %%
a = {0: 'a', 1: 'b', 2.2:'c'} 
print(a[0]) # => 'a'
print(a[2.2]) # => 'c'
# Out:
# a
# c

# %% [markdown]
# ## Mutable

# %%
a = {'a': 1, 'b': 3, 'c': 5, 'd': 7} 
a['d'] = 9; print(a) # => {'a': 1, 'b': 3, 'c': 5, 'd': 9}
# Out:
# {'a': 1, 'b': 3, 'c': 5, 'd': 9}

# %% [markdown]
# ## len

# %%
a = {'a': 1, 'b': 3, 'c': 5, 'd': 7} 
print(len(a)) # => 4
# Out:
# 4

# %% [markdown]
# ## Addition

# %%
a = {} 
a['a'] = 1 # => {'a': 1} 
a['b'] = 2 # => {'a': 1, 'b': 2} 
print(a)
# Out:
# {'a': 1, 'b': 2}

# %% [markdown]
# ## Deletion

# %%
a = {} 
a['a'] = 1 # => {'a': 1} 
a['b'] = 2 # => {'a': 1, 'b': 2} 
del a['a'] # => {'b': 2} 
print(a)
# Out:
# {'b': 2}

# %% [markdown]
# # Nest Dict { }

# %%
family = {'grandpa': 'Jay', 'parent':['Peter', 'Lynn'], 'children':{'bro': 'Ping', 'sis': 'Xi'}}
family['grandpa']         ; print(family['grandpa'])
family['parent']          ; print(family['parent'])
family['parent'][0]       ; print(family['parent'][0])
family['children']        ; print(family['children'])
family['children']['bro'] ; print(family['children']['bro'])
# Out:
# Jay
# ['Peter', 'Lynn']
# Peter
# {'bro': 'Ping', 'sis': 'Xi'}
# Ping

# %% [markdown]
# # Dynamic

# %% [markdown]
# ## update

# %%
a = {'a':1}
b = {'b':2, 'c':3}
a.update(b)
print(a)
# Out:
# {'a': 1, 'b': 2, 'c': 3}

# %% [markdown]
# ## clear

# %%
a = {'zero':0, 'one':1}
a.clear()
print(a)
# Out:
# {}

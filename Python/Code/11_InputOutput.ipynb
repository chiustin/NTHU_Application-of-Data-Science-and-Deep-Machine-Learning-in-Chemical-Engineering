# %% [markdown]
# # read()

# %%
f = open('file.txt', 'r')
f.read()
# Out:
# 'I Love David Shan-Hill Wong\nNTHUCHE5566\n'

# %% [markdown]
# # readline()

# %%
f = open('file.txt', 'r')
f.readline()
# Out:
# 'I Love David Shan-Hill Wong\n'

# %%
f.readline()
# Out:
# 'NTHUCHE5566\n'

# %%
f.readline()
# Out:
# ''

# %% [markdown]
# #

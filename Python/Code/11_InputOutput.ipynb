# %% [markdown]
# # Write

# %% [markdown]
# ## Create

# %%
f = open("writefile.txt", "w")
f.write('NTHUCHE')
f.close()

# %% [markdown]
# ## Append

# %%
f = open("writefile.txt", "a")
f.write('5566')
f.close()

# %% [markdown]
# # Overwrite

# %%
f = open("writefile.txt", "w")
f.write('NTHUCHE183')
f.close()

# %% [markdown]
# # Read

# %% [markdown]
# ## read()

# %%
f = open('file.txt', 'r')
f.read()
# Out:
# '*****I Love ***David Shan-Hill Wong*** very much*****\nNTHUCHE5566, NTHUCHE183.\n'

# %%
f.read()
# Out:
# ''

# %% [markdown]
# ## read(n)

# %%
f = open('file.txt', 'r')
f.read(5)
# Out:
# '*****'

# %%
f.read(6)
# Out:
# 'I Love'

# %%
f.read(42)
# Out:
# ' ***David Shan-Hill Wong*** very much*****'

# %%
f.read(1)
# Out:
# '\n'

# %%
f.read(11)
# Out:
# 'NTHUCHE5566'

# %%
f.read(2)
# Out:
# ', '

# %%
f.read(10)
# Out:
# 'NTHUCHE183'

# %%
f.read(10000000000000)
# Out:
# '.\n'

# %%
f.read(1)
# Out:
# ''

# %% [markdown]
# ## readline()

# %%
f = open('file.txt', 'r')
f.readline()
# Out:
# '*****I Love ***David Shan-Hill Wong*** very much*****\n'

# %%
f.readline()
# Out:
# 'NTHUCHE5566, NTHUCHE183.\n'

# %%
f.readline()
# Out:
# ''

# %% [markdown]
# ## Loop over the File Object

# %%
f = open('file.txt', 'r')
a = []
i = 0
for line in f:
    print('line', i,'=',line)
    a.append(line)
    i += 1
   
print('----------------------------------------------------------------------------------------------------')
print('a    =', a)
print('a[0] =',a[0])
print('a[1] =',a[1])
# Out:
# line 0 = *****I Love ***David Shan-Hill Wong*** very much*****
#
# line 1 = NTHUCHE5566, NTHUCHE183.
#
# ----------------------------------------------------------------------------------------------------
# a    = ['*****I Love ***David Shan-Hill Wong*** very much*****\n', 'NTHUCHE5566, NTHUCHE183.\n']
# a[0] = *****I Love ***David Shan-Hill Wong*** very much*****
#
# a[1] = NTHUCHE5566, NTHUCHE183.

# %% [markdown]
# ## lstrip(), rstrip(), strip()

# %%
f = open('file.txt', 'r')
a = []
for line in f:
    a.append(line)

print('list a =', a)
print('lstrip =', a[0].lstrip('*'))
print('rstrip =', a[0].rstrip('*')) # a[0][-1] = '\n'
print('rstrip =', a[0][:-1].rstrip('*'))
print('strip  =', a[0][:-1].strip('*'))
# Out:
# list a = ['*****I Love ***David Shan-Hill Wong*** very much*****\n', 'NTHUCHE5566, NTHUCHE183.\n']
# lstrip = I Love ***David Shan-Hill Wong*** very much*****
#
# rstrip = *****I Love ***David Shan-Hill Wong*** very much*****
#
# rstrip = *****I Love ***David Shan-Hill Wong*** very much
# strip  = I Love ***David Shan-Hill Wong*** very much

# %% [markdown]
# ## replace()

# %%
f = open('file.txt', 'r')
a = []
for line in f:
    #print(line)
    a.append(line)
    
print('list a   =', a)
print('replace  =', a[1].replace(',', ''))
print('replace  =', a[1].replace(',', '').replace('.', ''))
# Out:
# list a   = ['*****I Love ***David Shan-Hill Wong*** very much*****\n', 'NTHUCHE5566, NTHUCHE183.\n']
# replace  = NTHUCHE5566 NTHUCHE183.
#
# replace  = NTHUCHE5566 NTHUCHE183

# %% [markdown]
# ## split()

# %%
f = open('file.txt', 'r')
a = []
for line in f:
    a.append(line)

a1 = a[1].replace(',','').replace('.','')
print('split    =', a1.split())
print('split[0] =', a1.split()[0])
print('split[1] =', a1.split()[1])
# Out:
# split    = ['NTHUCHE5566', 'NTHUCHE183']
# split[0] = NTHUCHE5566
# split[1] = NTHUCHE183

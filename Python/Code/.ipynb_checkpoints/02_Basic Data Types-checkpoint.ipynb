# %% [markdown]
# # Type

# %%
print( 1450, type(1450) )
print( 9.2, type(9.2) )
print( 8+9j, type(8+9j) )
print( 'NTHUCHE', type('NTHUCHE') )
print( "NTHUCHE", type("NTHUCHE") )
print( True, type(True) )
print( False, type(True) )
# Out:
# 1450 <class 'int'>
# 9.2 <class 'float'>
# (8+9j) <class 'complex'>
# NTHUCHE <class 'str'>
# NTHUCHE <class 'str'>
# True <class 'bool'>
# False <class 'bool'>

# %% [markdown]
# # Floating-Point Numbers

# %%
print(1.)
print(.1)
print(8e7)
print(9e-2)
print(1.79e308)
print(1.8e308)
print(5e-324)
print(1e-325)
# Out:
# 1.0
# 0.1
# 80000000.0
# 0.09
# 1.79e+308
# inf
# 5e-324
# 0.0

# %% [markdown]
# # Casting

# %%
print(int(9.2))
print(float(1450))
print(str(5566))
print(bool(0), bool(1), bool(831))
# Out:
# 9
# 1450.0
# 5566
# False True True

# %%
print('NTHU'+5566)
# Out:
# ---------------------------------------------------
# TypeError         Traceback (most recent call last)
# <ipython-input-4-b55069dc8fdd> in <module>
# ----> 1 print('NTHU'+5566)
#
# TypeError: can only concatenate str (not "int") to str

# %%
print('NTHU'+str(5566))
# Out:
# NTHU5566

# %% [markdown]
# # Boolean

# %%
print(1 == 1)

# %%
print(1+True)
print(1+False)
print(2*True)
print(2*False)

# %% [markdown]
# # Python Operator Precedence

# %%
1 + 2 -1
# Out:
# 2

# %%
1 + 2 * 3
# Out:
# 7

# %%
1 + 2 ** 4 * 2
# Out:
# 33

# %% [markdown]
# # Mathematical functions

# %% [markdown]
# ## Power and logarithmic functions

# %%
import math
print(math.exp(1))
print(math.log(100,10))
print(math.log(4,2))
print(math.sqrt(4))
# Out:
# 2.718281828459045
# 2.0
# 2.0
# 2.0

# %% [markdown]
# ## Constants

# %%
import math
print(math.pi)
print(math.e)
# Out:
# 3.141592653589793
# 2.718281828459045

# %% [markdown]
# ## Angular conversion

# %%
import math
print(math.degrees(math.pi))
print(math.radians(180))
# Out:
# 180.0
# 3.141592653589793

# %% [markdown]
# ## Trigonometric functions

# %%
import math
print(math.acos(0))
print(math.asin(1))
print(math.atan(-1))
print( math.cos( math.radians(60) ) )
print( math.sin( math.radians(30) ) )
print( math.tan( math.radians(45) ) )
math.radians(180)
# Out:
# 1.5707963267948966
# 1.5707963267948966
# -0.7853981633974483
# 0.5000000000000001
# 0.49999999999999994
# 0.9999999999999999
# 3.141592653589793

# %% [markdown]
# ## Hyperbolic functions

# %%
import math
math.acosh(x)
math.asinh(x)
math.atanh(x)
math.cosh(x)
math.sinh(x)
math.tanh(x)
